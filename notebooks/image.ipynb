# %%
# loop through a folder and show first 5 images
from pathlib import Path
from PIL import Image
# sort by name
for i, img in enumerate(sorted(Path('/Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective').glob('*.png'))):
    if i < 5:
        print(img)
        display(Image.open(img))
    else:
        break
# Out:
# /Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective/--48PcezsniUyuyomHXWjQ_Direction_0_FOV_90_aspect_9--16_raw.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x225>
# /Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective/--48PcezsniUyuyomHXWjQ_Direction_180_FOV_90_aspect_9--16_raw.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x225>
# /Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective/--48PcezsniUyuyomHXWjQ_Direction_270_FOV_90_aspect_9--16_raw.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x225>
# /Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective/--48PcezsniUyuyomHXWjQ_Direction_90_FOV_90_aspect_9--16_raw.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x225>
# /Volumes/ExFAT/road_shoulder_gan/data/raw/road_shoulder/gsv/image/perspective/--MCxdTMD_siKgyPliZ7Sg_Direction_0_FOV_90_aspect_9--16_raw.png
# ...
